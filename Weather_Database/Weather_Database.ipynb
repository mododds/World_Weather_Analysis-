# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set o f random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | bluefield
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | bilibino
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | finschhafen
# Processing Record 17 of Set 1 | vangaindrano
# Processing Record 18 of Set 1 | excelsior springs
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 1 | tiarei
# Processing Record 22 of Set 1 | neryungri
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | rovaniemi
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | seddon
# Processing Record 28 of Set 1 | walvis bay
# Processing Record 29 of Set 1 | zhigansk
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | abu dhabi
# Processing Record 32 of Set 1 | churapcha
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | almeirim
# Processing Record 36 of Set 1 | san andres
# Processing Record 37 of Set 1 | berlevag
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | port keats
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | moron
# Processing Record 42 of Set 1 | kasangulu
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | tromso
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | qixia
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | sistranda
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 2 | altay
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | camacha
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | araouane
# Processing Record 9 of Set 2 | dzaoudzi
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 12 of Set 2 | kyenjojo
# Processing Record 13 of Set 2 | bathsheba
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | dryden
# Processing Record 17 of Set 2 | qasigiannguit
# Processing Record 18 of Set 2 | meadow lake
# Processing Record 19 of Set 2 | kachug
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | otjimbingwe
# Processing Record 22 of Set 2 | chernyshevskiy
# Processing Record 23 of Set 2 | husavik
# Processing Record 24 of Set 2 | quatre cocos
# Processing Record 25 of Set 2 | morales
# Processing Record 26 of Set 2 | kieta
# Processing Record 27 of Set 2 | chuy
# Processing Record 28 of Set 2 | gao
# Processing Record 29 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 2 | leonberg
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | amahai
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | alofi
# Processing Record 37 of Set 2 | nador
# Processing Record 38 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 2 | bubaque
# Processing Record 40 of Set 2 | san cristobal
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | mamallapuram
# Processing Record 43 of Set 2 | verkhoyansk
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | praia
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | saint-raymond
# Processing Record 48 of Set 2 | raton
# Processing Record 49 of Set 2 | saldanha
# Processing Record 50 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 3 | yabrud
# Processing Record 2 of Set 3 | capao bonito
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | saint-joseph
# Processing Record 6 of Set 3 | play cu
# City not found. Skipping...
# Processing Record 7 of Set 3 | hambantota
# Processing Record 8 of Set 3 | beipiao
# Processing Record 9 of Set 3 | jalu
# Processing Record 10 of Set 3 | georgiyevka
# Processing Record 11 of Set 3 | hohhot
# Processing Record 12 of Set 3 | yartsevo
# Processing Record 13 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 3 | ampanihy
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 3 | coquimbo
# Processing Record 18 of Set 3 | moyale
# Processing Record 19 of Set 3 | sitka
# Processing Record 20 of Set 3 | coulihaut
# City not found. Skipping...
# Processing Record 21 of Set 3 | sheksna
# Processing Record 22 of Set 3 | lugovoy
# Processing Record 23 of Set 3 | marzuq
# Processing Record 24 of Set 3 | urucara
# Processing Record 25 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | hay river
# Processing Record 28 of Set 3 | ninghai
# Processing Record 29 of Set 3 | cururupu
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | santa cruz
# Processing Record 32 of Set 3 | ust-kuyga
# Processing Record 33 of Set 3 | aykhal
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | souillac
# Processing Record 36 of Set 3 | jinchang
# Processing Record 37 of Set 3 | merrill
# Processing Record 38 of Set 3 | sipkovica
# Processing Record 39 of Set 3 | tazovskiy
# Processing Record 40 of Set 3 | tornio
# Processing Record 41 of Set 3 | quime
# Processing Record 42 of Set 3 | mackay
# Processing Record 43 of Set 3 | suez
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | vaini
# Processing Record 46 of Set 3 | mitchell
# Processing Record 47 of Set 3 | korla
# Processing Record 48 of Set 3 | ancud
# Processing Record 49 of Set 3 | kolda
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | itabera
# Processing Record 2 of Set 4 | sembabule
# Processing Record 3 of Set 4 | kahului
# Processing Record 4 of Set 4 | padang
# Processing Record 5 of Set 4 | sibu
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | mehran
# Processing Record 8 of Set 4 | tautira
# Processing Record 9 of Set 4 | luanda
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | san vicente
# Processing Record 12 of Set 4 | namatanai
# Processing Record 13 of Set 4 | ilulissat
# Processing Record 14 of Set 4 | keti bandar
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 4 | tibiri
# Processing Record 18 of Set 4 | nantucket
# Processing Record 19 of Set 4 | kaitangata
# Processing Record 20 of Set 4 | masaka
# Processing Record 21 of Set 4 | at-bashi
# Processing Record 22 of Set 4 | los llanos de aridane
# Processing Record 23 of Set 4 | male
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | naze
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 4 | stabat
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | katsiveli
# City not found. Skipping...
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | krasnoselkup
# Processing Record 38 of Set 4 | hvide sande
# Processing Record 39 of Set 4 | vestmannaeyjar
# Processing Record 40 of Set 4 | zhicheng
# Processing Record 41 of Set 4 | usmajac
# Processing Record 42 of Set 4 | pangnirtung
# Processing Record 43 of Set 4 | atar
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | aklavik
# Processing Record 46 of Set 4 | kununurra
# Processing Record 47 of Set 4 | atuona
# Processing Record 48 of Set 4 | torva
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | villazon
# Processing Record 1 of Set 5 | portland
# Processing Record 2 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 5 | mahebourg
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | shemysheyka
# Processing Record 6 of Set 5 | santo antonio do ica
# Processing Record 7 of Set 5 | parati
# Processing Record 8 of Set 5 | tonantins
# Processing Record 9 of Set 5 | pestravka
# Processing Record 10 of Set 5 | sinnamary
# Processing Record 11 of Set 5 | sao filipe
# Processing Record 12 of Set 5 | yar-sale
# Processing Record 13 of Set 5 | rabaul
# Processing Record 14 of Set 5 | marsh harbour
# Processing Record 15 of Set 5 | orlik
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | salalah
# Processing Record 18 of Set 5 | santa vitoria do palmar
# Processing Record 19 of Set 5 | vung tau
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | dikson
# Processing Record 22 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | fukue
# Processing Record 25 of Set 5 | george
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | namibe
# Processing Record 28 of Set 5 | praia da vitoria
# Processing Record 29 of Set 5 | rio grande
# Processing Record 30 of Set 5 | champerico
# Processing Record 31 of Set 5 | sokoto
# Processing Record 32 of Set 5 | russell
# Processing Record 33 of Set 5 | balingasay
# Processing Record 34 of Set 5 | zwonitz
# Processing Record 35 of Set 5 | solnechnyy
# Processing Record 36 of Set 5 | upernavik
# Processing Record 37 of Set 5 | dwarka
# Processing Record 38 of Set 5 | scottsbluff
# Processing Record 39 of Set 5 | anadyr
# Processing Record 40 of Set 5 | khon kaen
# Processing Record 41 of Set 5 | east london
# Processing Record 42 of Set 5 | fairbanks
# Processing Record 43 of Set 5 | nyrob
# Processing Record 44 of Set 5 | sorong
# Processing Record 45 of Set 5 | zambezi
# Processing Record 46 of Set 5 | bilma
# Processing Record 47 of Set 5 | milkovo
# Processing Record 48 of Set 5 | deputatskiy
# Processing Record 49 of Set 5 | thompson
# Processing Record 50 of Set 5 | hailey
# Processing Record 1 of Set 6 | taldan
# Processing Record 2 of Set 6 | soyo
# Processing Record 3 of Set 6 | kupang
# Processing Record 4 of Set 6 | mazatlan
# Processing Record 5 of Set 6 | kangaatsiaq
# Processing Record 6 of Set 6 | san policarpo
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | mount gambier
# Processing Record 9 of Set 6 | eugene
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | te anau
# Processing Record 13 of Set 6 | zabaykalsk
# Processing Record 14 of Set 6 | tongling
# Processing Record 15 of Set 6 | manicore
# Processing Record 16 of Set 6 | malanje
# Processing Record 17 of Set 6 | hounde
# Processing Record 18 of Set 6 | reyes
# Processing Record 19 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 6 | hualmay
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 6 | palana
# Processing Record 24 of Set 6 | mathathane
# Processing Record 25 of Set 6 | cidreira
# Processing Record 26 of Set 6 | allen
# Processing Record 27 of Set 6 | helong
# Processing Record 28 of Set 6 | port hedland
# Processing Record 29 of Set 6 | taoudenni
# Processing Record 30 of Set 6 | sagar
# Processing Record 31 of Set 6 | ishigaki
# Processing Record 32 of Set 6 | acapulco
# Processing Record 33 of Set 6 | sovetskiy
# Processing Record 34 of Set 6 | coari
# Processing Record 35 of Set 6 | juneau
# Processing Record 36 of Set 6 | krasnovka
# Processing Record 37 of Set 6 | two hills
# Processing Record 38 of Set 6 | roald
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | voh
# Processing Record 41 of Set 6 | tomigusuku
# Processing Record 42 of Set 6 | kondinskoye
# Processing Record 43 of Set 6 | adrar
# Processing Record 44 of Set 6 | sola
# Processing Record 45 of Set 6 | eyl
# Processing Record 46 of Set 6 | aloleng
# Processing Record 47 of Set 6 | luwuk
# Processing Record 48 of Set 6 | muisne
# Processing Record 49 of Set 6 | ostrovnoy
# Processing Record 50 of Set 6 | provideniya
# Processing Record 1 of Set 7 | olafsvik
# Processing Record 2 of Set 7 | gravdal
# Processing Record 3 of Set 7 | chumikan
# Processing Record 4 of Set 7 | gorodishche
# Processing Record 5 of Set 7 | klaksvik
# Processing Record 6 of Set 7 | mporokoso
# Processing Record 7 of Set 7 | omsk
# Processing Record 8 of Set 7 | aksarka
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | lompoc
# Processing Record 11 of Set 7 | lovozero
# Processing Record 12 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 7 | lumut
# Processing Record 14 of Set 7 | kavaratti
# Processing Record 15 of Set 7 | paka
# Processing Record 16 of Set 7 | luderitz
# Processing Record 17 of Set 7 | srednekolymsk
# Processing Record 18 of Set 7 | quang ngai
# Processing Record 19 of Set 7 | longyearbyen
# Processing Record 20 of Set 7 | umm lajj
# Processing Record 21 of Set 7 | rio gallegos
# Processing Record 22 of Set 7 | waspan
# Processing Record 23 of Set 7 | lavrentiya
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | cafelandia
# Processing Record 26 of Set 7 | mecca
# Processing Record 27 of Set 7 | guadalupe victoria
# Processing Record 28 of Set 7 | saint-georges
# Processing Record 29 of Set 7 | ust-tsilma
# Processing Record 30 of Set 7 | oeiras
# Processing Record 31 of Set 7 | springfield
# Processing Record 32 of Set 7 | cessnock
# Processing Record 33 of Set 7 | puerto del rosario
# Processing Record 34 of Set 7 | nicoya
# Processing Record 35 of Set 7 | thanatpin
# Processing Record 36 of Set 7 | sisimiut
# Processing Record 37 of Set 7 | pevek
# Processing Record 38 of Set 7 | banov
# Processing Record 39 of Set 7 | baykit
# Processing Record 40 of Set 7 | mitsamiouli
# Processing Record 41 of Set 7 | ugoofaaru
# Processing Record 42 of Set 7 | la orilla
# Processing Record 43 of Set 7 | melfi
# Processing Record 44 of Set 7 | bagdarin
# Processing Record 45 of Set 7 | donghai
# Processing Record 46 of Set 7 | kodyma
# Processing Record 47 of Set 7 | evensk
# Processing Record 48 of Set 7 | banda aceh
# Processing Record 49 of Set 7 | washington
# Processing Record 50 of Set 7 | quartucciu
# Processing Record 1 of Set 8 | andenes
# Processing Record 2 of Set 8 | durham
# Processing Record 3 of Set 8 | chapais
# Processing Record 4 of Set 8 | inhambane
# Processing Record 5 of Set 8 | tiksi
# Processing Record 6 of Set 8 | boueni
# Processing Record 7 of Set 8 | ordynskoye
# Processing Record 8 of Set 8 | souris
# Processing Record 9 of Set 8 | kulachi
# Processing Record 10 of Set 8 | chadan
# Processing Record 11 of Set 8 | ust-uda
# Processing Record 12 of Set 8 | maracacume
# Processing Record 13 of Set 8 | suntar
# Processing Record 14 of Set 8 | jefferson city
# Processing Record 15 of Set 8 | barkhan
# Processing Record 16 of Set 8 | emba
# Processing Record 17 of Set 8 | uniao da victoria
# City not found. Skipping...
# Processing Record 18 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 8 | troitskoye
# Processing Record 20 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 8 | clinton
# Processing Record 22 of Set 8 | bud
# Processing Record 23 of Set 8 | banepa
# Processing Record 24 of Set 8 | butterworth
# Processing Record 25 of Set 8 | burica
# City not found. Skipping...
# Processing Record 26 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 8 | ranong
# Processing Record 28 of Set 8 | fonte boa
# Processing Record 29 of Set 8 | airai
# Processing Record 30 of Set 8 | lake city
# Processing Record 31 of Set 8 | halifax
# Processing Record 32 of Set 8 | ambon
# Processing Record 33 of Set 8 | guisa
# Processing Record 34 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 8 | koungou
# Processing Record 36 of Set 8 | lufilufi
# Processing Record 37 of Set 8 | srivardhan
# Processing Record 38 of Set 8 | broken hill
# Processing Record 39 of Set 8 | cherskiy
# Processing Record 40 of Set 8 | qaqortoq
# Processing Record 41 of Set 8 | ontario
# Processing Record 42 of Set 8 | hemnesberget
# Processing Record 43 of Set 8 | georgetown
# Processing Record 44 of Set 8 | pochutla
# Processing Record 45 of Set 8 | okhotsk
# Processing Record 46 of Set 8 | sigli
# Processing Record 47 of Set 8 | bichura
# Processing Record 48 of Set 8 | pitimbu
# Processing Record 49 of Set 8 | marawi
# Processing Record 50 of Set 8 | ust-nera
# Processing Record 1 of Set 9 | yulara
# Processing Record 2 of Set 9 | morondava
# Processing Record 3 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 9 | santo domingo
# Processing Record 5 of Set 9 | saint-francois
# Processing Record 6 of Set 9 | sawtell
# Processing Record 7 of Set 9 | shellbrook
# Processing Record 8 of Set 9 | bull savanna
# Processing Record 9 of Set 9 | fortuna
# Processing Record 10 of Set 9 | rabak
# Processing Record 11 of Set 9 | meulaboh
# Processing Record 12 of Set 9 | kinkala
# Processing Record 13 of Set 9 | arvika
# Processing Record 14 of Set 9 | richards bay
# Processing Record 15 of Set 9 | malindi
# Processing Record 16 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 9 | darab
# Processing Record 18 of Set 9 | inirida
# Processing Record 19 of Set 9 | santo angelo
# Processing Record 20 of Set 9 | norman wells
# Processing Record 21 of Set 9 | ikalamavony
# Processing Record 22 of Set 9 | pervomayskoye
# Processing Record 23 of Set 9 | termoli
# Processing Record 24 of Set 9 | dawei
# Processing Record 25 of Set 9 | hammerfest
# Processing Record 26 of Set 9 | qaanaaq
# Processing Record 27 of Set 9 | dharchula
# Processing Record 28 of Set 9 | siedlce
# Processing Record 29 of Set 9 | ahipara
# Processing Record 30 of Set 9 | vallenar
# Processing Record 31 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 9 | abnub
# Processing Record 33 of Set 9 | carmen
# Processing Record 34 of Set 9 | leeton
# Processing Record 35 of Set 9 | jiexiu
# Processing Record 36 of Set 9 | aksu
# Processing Record 37 of Set 9 | glogow
# Processing Record 38 of Set 9 | tezu
# Processing Record 39 of Set 9 | chimbote
# Processing Record 40 of Set 9 | debre sina
# Processing Record 41 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 9 | smithers
# Processing Record 43 of Set 9 | barranca
# Processing Record 44 of Set 9 | akita
# Processing Record 45 of Set 9 | paamiut
# Processing Record 46 of Set 9 | colesberg
# Processing Record 47 of Set 9 | general roca
# Processing Record 48 of Set 9 | severo-kurilsk
# Processing Record 49 of Set 9 | roebourne
# Processing Record 50 of Set 9 | mount isa
# Processing Record 1 of Set 10 | kayerkan
# Processing Record 2 of Set 10 | mason city
# Processing Record 3 of Set 10 | agstafa
# City not found. Skipping...
# Processing Record 4 of Set 10 | mayumba
# Processing Record 5 of Set 10 | wanning
# Processing Record 6 of Set 10 | damietta
# Processing Record 7 of Set 10 | paita
# Processing Record 8 of Set 10 | kasongo-lunda
# Processing Record 9 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 10 | north battleford
# Processing Record 11 of Set 10 | tilichiki
# Processing Record 12 of Set 10 | langen
# Processing Record 13 of Set 10 | batagay-alyta
# Processing Record 14 of Set 10 | zwedru
# Processing Record 15 of Set 10 | the valley
# Processing Record 16 of Set 10 | shambu
# Processing Record 17 of Set 10 | lekoni
# Processing Record 18 of Set 10 | cayenne
# Processing Record 19 of Set 10 | waingapu
# Processing Record 20 of Set 10 | shahreza
# Processing Record 21 of Set 10 | jaguariaiva
# Processing Record 22 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 10 | sona
# Processing Record 24 of Set 10 | aasiaat
# Processing Record 25 of Set 10 | victoria point
# Processing Record 26 of Set 10 | isangel
# Processing Record 27 of Set 10 | hofn
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | ha tinh
# Processing Record 30 of Set 10 | mazagao
# Processing Record 31 of Set 10 | mizdah
# Processing Record 32 of Set 10 | maunatlala
# Processing Record 33 of Set 10 | lhuntshi
# City not found. Skipping...
# Processing Record 34 of Set 10 | punta alta
# Processing Record 35 of Set 10 | kushima
# Processing Record 36 of Set 10 | pokanayevka
# City not found. Skipping...
# Processing Record 37 of Set 10 | aosta
# Processing Record 38 of Set 10 | rupert
# Processing Record 39 of Set 10 | severomuysk
# Processing Record 40 of Set 10 | touros
# Processing Record 41 of Set 10 | yarada
# Processing Record 42 of Set 10 | svobodnyy
# Processing Record 43 of Set 10 | gujranwala
# Processing Record 44 of Set 10 | teya
# Processing Record 45 of Set 10 | akyab
# Processing Record 46 of Set 10 | pimenta bueno
# Processing Record 47 of Set 10 | cape elizabeth
# City not found. Skipping...
# Processing Record 48 of Set 10 | tessalit
# Processing Record 49 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 10 | copiapo
# Processing Record 1 of Set 11 | mar del plata
# Processing Record 2 of Set 11 | puerto rico
# Processing Record 3 of Set 11 | sorland
# Processing Record 4 of Set 11 | libertador general san martin
# Processing Record 5 of Set 11 | katherine
# Processing Record 6 of Set 11 | mazamari
# Processing Record 7 of Set 11 | zhangye
# Processing Record 8 of Set 11 | grindavik
# Processing Record 9 of Set 11 | varkkallai
# Processing Record 10 of Set 11 | sao jose da coroa grande
# Processing Record 11 of Set 11 | madang
# Processing Record 12 of Set 11 | medicine hat
# Processing Record 13 of Set 11 | raudeberg
# Processing Record 14 of Set 11 | matara
# Processing Record 15 of Set 11 | osa
# Processing Record 16 of Set 11 | ucluelet
# Processing Record 17 of Set 11 | labuhan
# Processing Record 18 of Set 11 | caravelas
# Processing Record 19 of Set 11 | mangrol
# Processing Record 20 of Set 11 | arlit
# Processing Record 21 of Set 11 | puerto leguizamo
# Processing Record 22 of Set 11 | vardo
# Processing Record 23 of Set 11 | peace river
# Processing Record 24 of Set 11 | samfya
# Processing Record 25 of Set 11 | flinders
# Processing Record 26 of Set 11 | tateyama
# Processing Record 27 of Set 11 | mayo
# Processing Record 28 of Set 11 | roma
# Processing Record 29 of Set 11 | homer
# Processing Record 30 of Set 11 | luis correia
# Processing Record 31 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 11 | puerto madryn
# Processing Record 33 of Set 11 | belle fourche
# Processing Record 34 of Set 11 | young
# Processing Record 35 of Set 11 | gabu
# Processing Record 36 of Set 11 | doha
# Processing Record 37 of Set 11 | hitachi
# Processing Record 38 of Set 11 | visnes
# Processing Record 39 of Set 11 | arrifes
# Processing Record 40 of Set 11 | zyryanka
# Processing Record 41 of Set 11 | poum
# Processing Record 42 of Set 11 | cap malheureux
# Processing Record 43 of Set 11 | kamenskiy
# Processing Record 44 of Set 11 | paris
# Processing Record 45 of Set 11 | beringovskiy
# Processing Record 46 of Set 11 | knysna
# Processing Record 47 of Set 11 | pemba
# Processing Record 48 of Set 11 | bambanglipuro
# Processing Record 49 of Set 11 | langsa
# Processing Record 50 of Set 11 | skelleftea
# Processing Record 1 of Set 12 | lagos
# Processing Record 2 of Set 12 | southbridge
# Processing Record 3 of Set 12 | radzyn podlaski
# Processing Record 4 of Set 12 | kualakapuas
# Processing Record 5 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 6 of Set 12 | constitucion
# Processing Record 7 of Set 12 | moquegua
# Processing Record 8 of Set 12 | vostok
# Processing Record 9 of Set 12 | gat
# Processing Record 10 of Set 12 | zhezkazgan
# Processing Record 11 of Set 12 | rundu
# Processing Record 12 of Set 12 | zlynka
# Processing Record 13 of Set 12 | tura
# Processing Record 14 of Set 12 | samarai
# Processing Record 15 of Set 12 | belaya gora
# Processing Record 16 of Set 12 | grosuplje
# Processing Record 17 of Set 12 | santos reyes nopala
# Processing Record 18 of Set 12 | balabac
# Processing Record 19 of Set 12 | glendive
# Processing Record 20 of Set 12 | santa fe
# Processing Record 21 of Set 12 | svetlogorsk
# Processing Record 22 of Set 12 | cambridge
# Processing Record 23 of Set 12 | plettenberg bay
# Processing Record 24 of Set 12 | aksehir
# Processing Record 25 of Set 12 | tevaitoa
# Processing Record 26 of Set 12 | muscat
# Processing Record 27 of Set 12 | laguna
# Processing Record 28 of Set 12 | sabang
# Processing Record 29 of Set 12 | nalut
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | swift current
# Processing Record 32 of Set 12 | cochrane
# Processing Record 33 of Set 12 | xinzhou
# Processing Record 34 of Set 12 | odweyne
# Processing Record 35 of Set 12 | olinda
# Processing Record 36 of Set 12 | sao joao da barra
# Processing Record 37 of Set 12 | kumla
# Processing Record 38 of Set 12 | la romana
# Processing Record 39 of Set 12 | omsukchan
# Processing Record 40 of Set 12 | chara
# Processing Record 41 of Set 12 | biak
# Processing Record 42 of Set 12 | el tigre
# Processing Record 43 of Set 12 | hami
# Processing Record 44 of Set 12 | prince rupert
# Processing Record 45 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 12 | karratha
# Processing Record 47 of Set 12 | channel-port aux basques
# Processing Record 48 of Set 12 | nata
# Processing Record 49 of Set 12 | duku
# Processing Record 50 of Set 12 | maniitsoq
# Processing Record 1 of Set 13 | edd
# Processing Record 2 of Set 13 | lata
# Processing Record 3 of Set 13 | remanso
# Processing Record 4 of Set 13 | ondjiva
# Processing Record 5 of Set 13 | bonfim
# Processing Record 6 of Set 13 | hoi an
# Processing Record 7 of Set 13 | kilindoni
# Processing Record 8 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 13 | coahuayana
# Processing Record 10 of Set 13 | freeport
# Processing Record 11 of Set 13 | aurdal
# Processing Record 12 of Set 13 | vila franca do campo
# Processing Record 13 of Set 13 | oktyabrskoye
# Processing Record 14 of Set 13 | huarmey
# Processing Record 15 of Set 13 | auki
# Processing Record 16 of Set 13 | asau
# Processing Record 17 of Set 13 | sobolevo
# Processing Record 18 of Set 13 | snyder
# Processing Record 19 of Set 13 | san jose
# Processing Record 20 of Set 13 | talcahuano
# Processing Record 21 of Set 13 | casablanca
# Processing Record 22 of Set 13 | brae
# Processing Record 23 of Set 13 | sept-iles
# Processing Record 24 of Set 13 | santiago del estero
# Processing Record 25 of Set 13 | portree
# Processing Record 26 of Set 13 | great falls
# Processing Record 27 of Set 13 | honningsvag
# Processing Record 28 of Set 13 | kigoma
# Processing Record 29 of Set 13 | north auburn
# Processing Record 30 of Set 13 | jenks
# Processing Record 31 of Set 13 | sheltozero
# Processing Record 32 of Set 13 | severodvinsk
# Processing Record 33 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 13 | abu samrah
# Processing Record 35 of Set 13 | kedrovyy
# Processing Record 36 of Set 13 | praxedis guerrero
# Processing Record 37 of Set 13 | consett
# Processing Record 38 of Set 13 | veraval
# Processing Record 39 of Set 13 | orhei
# Processing Record 40 of Set 13 | nouadhibou
# Processing Record 41 of Set 13 | la gomera
# Processing Record 42 of Set 13 | skuratovskiy
# Processing Record 43 of Set 13 | casper
# Processing Record 44 of Set 13 | zaysan
# Processing Record 45 of Set 13 | havelock
# Processing Record 46 of Set 13 | watertown
# Processing Record 47 of Set 13 | san quintin
# Processing Record 48 of Set 13 | inta
# Processing Record 49 of Set 13 | hamilton
# Processing Record 50 of Set 13 | severo-yeniseyskiy
# Processing Record 1 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 14 | pasni
# Processing Record 3 of Set 14 | grand gaube
# Processing Record 4 of Set 14 | molepolole
# Processing Record 5 of Set 14 | pudozh
# Processing Record 6 of Set 14 | porto de moz
# Processing Record 7 of Set 14 | mugur-aksy
# Processing Record 8 of Set 14 | avanigadda
# Processing Record 9 of Set 14 | fare
# Processing Record 10 of Set 14 | winslow
# Processing Record 11 of Set 14 | ouegoa
# Processing Record 12 of Set 14 | paracuru
# Processing Record 13 of Set 14 | likhoslavl
# Processing Record 14 of Set 14 | lamu
# Processing Record 15 of Set 14 | port-gentil
# Processing Record 16 of Set 14 | terrace
# Processing Record 17 of Set 14 | dakar
# Processing Record 18 of Set 14 | koraput
# Processing Record 19 of Set 14 | lorengau
# Processing Record 20 of Set 14 | lipin bor
# Processing Record 21 of Set 14 | bangkal
# Processing Record 22 of Set 14 | shu
# Processing Record 23 of Set 14 | katsuura
# Processing Record 24 of Set 14 | saurimo
# Processing Record 25 of Set 14 | gidam
# Processing Record 26 of Set 14 | porto novo
# Processing Record 27 of Set 14 | victor harbor
# Processing Record 28 of Set 14 | dunedin
# Processing Record 29 of Set 14 | seoul
# Processing Record 30 of Set 14 | bairiki
# Processing Record 31 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 14 | byron bay
# Processing Record 33 of Set 14 | pacific grove
# Processing Record 34 of Set 14 | promysla
# City not found. Skipping...
# Processing Record 35 of Set 14 | birin
# Processing Record 36 of Set 14 | marsa matruh
# Processing Record 37 of Set 14 | nago
# Processing Record 38 of Set 14 | ternate
# Processing Record 39 of Set 14 | lokhvytsya
# Processing Record 40 of Set 14 | svirstroy
# Processing Record 41 of Set 14 | arucas
# Processing Record 42 of Set 14 | port blair
# Processing Record 43 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 14 | ramasukha
# City not found. Skipping...
# Processing Record 45 of Set 14 | cap-aux-meules
# Processing Record 46 of Set 14 | saint anthony
# Processing Record 47 of Set 14 | salawagan
# Processing Record 48 of Set 14 | karpogory
# Processing Record 49 of Set 14 | lebyazhye
# Processing Record 50 of Set 14 | pimentel
# Processing Record 1 of Set 15 | mandali
# Processing Record 2 of Set 15 | shubarkuduk
# Processing Record 3 of Set 15 | abdanan
# Processing Record 4 of Set 15 | port lincoln
# Processing Record 5 of Set 15 | ivangorod
# Processing Record 6 of Set 15 | progreso
# Processing Record 7 of Set 15 | gubkinskiy
# Processing Record 8 of Set 15 | tocopilla
# Processing Record 9 of Set 15 | san jeronimo
# Processing Record 10 of Set 15 | brazzaville
# Processing Record 11 of Set 15 | yenagoa
# Processing Record 12 of Set 15 | krasnopavlivka
# Processing Record 13 of Set 15 | jiayuguan
# Processing Record 14 of Set 15 | sumbe
# Processing Record 15 of Set 15 | ayame
# Processing Record 16 of Set 15 | san blas
# Processing Record 17 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 15 | filadelfia
# Processing Record 19 of Set 15 | ersekcsanad
# Processing Record 20 of Set 15 | artesia
# Processing Record 21 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 15 | san cataldo
# Processing Record 23 of Set 15 | shaowu
# Processing Record 24 of Set 15 | fallon
# Processing Record 25 of Set 15 | hwange
# Processing Record 26 of Set 15 | ballina
# Processing Record 27 of Set 15 | buin
# Processing Record 28 of Set 15 | ust-karsk
# Processing Record 29 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 15 | ambilobe
# Processing Record 31 of Set 15 | alekseyevskaya
# Processing Record 32 of Set 15 | namtsy
# Processing Record 33 of Set 15 | przhevalskoye
# Processing Record 34 of Set 15 | northam
# Processing Record 35 of Set 15 | shujaabad
# Processing Record 36 of Set 15 | kelso
# Processing Record 37 of Set 15 | mugumu
# Processing Record 38 of Set 15 | mariental
# Processing Record 39 of Set 15 | mumford
# Processing Record 40 of Set 15 | xinyu
# Processing Record 41 of Set 15 | conde
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Guerrero Negro  27.9769 -114.0611     59.85        75         100
# 1         Mataura -46.1927  168.8643     58.48        45          12
# 2          Albany  42.6001  -73.9662     39.72        62          18
# 3            Hilo  19.7297 -155.0900     73.13        50          75
# 4       Bluefield  37.2698  -81.2223     30.76        68           1
#
#    Wind Speed Current Description
# 0        9.13     overcast clouds
# 1        5.86          few clouds
# 2        4.88          few clouds
# 3        5.75          light rain
# 4        1.01           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set o f random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | saint george
# Processing Record 4 of Set 1 | tambura
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | yangjiang
# Processing Record 7 of Set 1 | vista hermosa
# Processing Record 8 of Set 1 | paris
# Processing Record 9 of Set 1 | salinas
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 1 | kutum
# Processing Record 18 of Set 1 | yumen
# Processing Record 19 of Set 1 | yerbogachen
# Processing Record 20 of Set 1 | ixtapa
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | narsaq
# Processing Record 25 of Set 1 | sinnamary
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | santiago del estero
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | beira
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | cockburn town
# Processing Record 33 of Set 1 | asau
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | taltal
# Processing Record 36 of Set 1 | verkhoyansk
# Processing Record 37 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | poum
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 1 | egvekinot
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | nisia floresta
# Processing Record 49 of Set 1 | west odessa
# Processing Record 50 of Set 1 | shepsi
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | grand gaube
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | qingdao
# Processing Record 6 of Set 2 | bolobo
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | lavrentiya
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | cavalcante
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | te anau
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | waipawa
# Processing Record 19 of Set 2 | los llanos de aridane
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | whitehorse
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | frisco
# Processing Record 25 of Set 2 | prata
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | chongqing
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | sorland
# Processing Record 34 of Set 2 | dicabisagan
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | ukiah
# Processing Record 39 of Set 2 | qunduz
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | flinders
# Processing Record 45 of Set 2 | clyde river
# Processing Record 46 of Set 2 | prince albert
# Processing Record 47 of Set 2 | terrak
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | portland
# Processing Record 50 of Set 2 | tocopilla
# Processing Record 1 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 3 | gamba
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | kyra
# Processing Record 6 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | kharabali
# Processing Record 9 of Set 3 | tramandai
# Processing Record 10 of Set 3 | puerto escondido
# Processing Record 11 of Set 3 | viedma
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | port blair
# Processing Record 14 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | bakonyszentlaszlo
# Processing Record 18 of Set 3 | sturgeon bay
# Processing Record 19 of Set 3 | hualmay
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | provideniya
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | morro bay
# Processing Record 26 of Set 3 | waingapu
# Processing Record 27 of Set 3 | tura
# Processing Record 28 of Set 3 | bilma
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | san patricio
# Processing Record 31 of Set 3 | yar-sale
# Processing Record 32 of Set 3 | saint-joseph
# Processing Record 33 of Set 3 | kalmunai
# Processing Record 34 of Set 3 | healdsburg
# Processing Record 35 of Set 3 | mopti
# Processing Record 36 of Set 3 | kazachinskoye
# Processing Record 37 of Set 3 | casas grandes
# Processing Record 38 of Set 3 | russell
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 3 | poronaysk
# Processing Record 42 of Set 3 | lompoc
# Processing Record 43 of Set 3 | neuquen
# Processing Record 44 of Set 3 | boende
# Processing Record 45 of Set 3 | port-gentil
# Processing Record 46 of Set 3 | saint-philippe
# Processing Record 47 of Set 3 | wuwei
# Processing Record 48 of Set 3 | mackay
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 4 | port hardy
# Processing Record 2 of Set 4 | luoyang
# Processing Record 3 of Set 4 | guerrero negro
# Processing Record 4 of Set 4 | baldone
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | mbacke
# City not found. Skipping...
# Processing Record 7 of Set 4 | grindavik
# Processing Record 8 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 4 | tautira
# Processing Record 10 of Set 4 | aykhal
# Processing Record 11 of Set 4 | amasya
# Processing Record 12 of Set 4 | dawson creek
# Processing Record 13 of Set 4 | vestmanna
# Processing Record 14 of Set 4 | domoni
# Processing Record 15 of Set 4 | seredka
# Processing Record 16 of Set 4 | saskylakh
# Processing Record 17 of Set 4 | biak
# Processing Record 18 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 4 | amahai
# Processing Record 20 of Set 4 | luderitz
# Processing Record 21 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 22 of Set 4 | kontagora
# Processing Record 23 of Set 4 | san ramon
# Processing Record 24 of Set 4 | iroquois falls
# Processing Record 25 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 4 | pulandian
# Processing Record 28 of Set 4 | cabedelo
# Processing Record 29 of Set 4 | nabire
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | santa barbara
# Processing Record 32 of Set 4 | floro
# Processing Record 33 of Set 4 | whitianga
# Processing Record 34 of Set 4 | makakilo city
# Processing Record 35 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 4 | kenai
# Processing Record 38 of Set 4 | rocha
# Processing Record 39 of Set 4 | piraju
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | pinczow
# Processing Record 42 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 43 of Set 4 | kulunda
# Processing Record 44 of Set 4 | skovorodino
# Processing Record 45 of Set 4 | peterhead
# Processing Record 46 of Set 4 | itupiranga
# Processing Record 47 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | amapa
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | turinskaya sloboda
# Processing Record 2 of Set 5 | sao gabriel da cachoeira
# Processing Record 3 of Set 5 | lock haven
# Processing Record 4 of Set 5 | liaocheng
# Processing Record 5 of Set 5 | acapulco
# Processing Record 6 of Set 5 | tuatapere
# Processing Record 7 of Set 5 | naze
# Processing Record 8 of Set 5 | peniche
# Processing Record 9 of Set 5 | andros town
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 12 of Set 5 | auki
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | alofi
# Processing Record 15 of Set 5 | naron
# Processing Record 16 of Set 5 | itarema
# Processing Record 17 of Set 5 | lianran
# Processing Record 18 of Set 5 | airai
# Processing Record 19 of Set 5 | bethel
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | nouakchott
# Processing Record 22 of Set 5 | westport
# Processing Record 23 of Set 5 | miechow
# Processing Record 24 of Set 5 | karratha
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | san jeronimo
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | caruray
# Processing Record 29 of Set 5 | lorengau
# Processing Record 30 of Set 5 | vao
# Processing Record 31 of Set 5 | bamiantong
# Processing Record 32 of Set 5 | amberley
# Processing Record 33 of Set 5 | jardim do serido
# Processing Record 34 of Set 5 | turtkul
# City not found. Skipping...
# Processing Record 35 of Set 5 | ishigaki
# Processing Record 36 of Set 5 | luganville
# Processing Record 37 of Set 5 | virbhadra
# Processing Record 38 of Set 5 | khatanga
# Processing Record 39 of Set 5 | kodiak
# Processing Record 40 of Set 5 | alto araguaia
# Processing Record 41 of Set 5 | sur
# Processing Record 42 of Set 5 | talara
# Processing Record 43 of Set 5 | saryg-sep
# Processing Record 44 of Set 5 | abu samrah
# Processing Record 45 of Set 5 | vostok
# Processing Record 46 of Set 5 | ovsyanka
# Processing Record 47 of Set 5 | srednekolymsk
# Processing Record 48 of Set 5 | ostrovnoy
# Processing Record 49 of Set 5 | kraslava
# Processing Record 50 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | klenovyy
# Processing Record 3 of Set 6 | tabou
# Processing Record 4 of Set 6 | nesbyen
# Processing Record 5 of Set 6 | half moon bay
# Processing Record 6 of Set 6 | kruisfontein
# Processing Record 7 of Set 6 | mogochin
# City not found. Skipping...
# Processing Record 8 of Set 6 | paamiut
# Processing Record 9 of Set 6 | dedovichi
# Processing Record 10 of Set 6 | lodi
# Processing Record 11 of Set 6 | tayu
# Processing Record 12 of Set 6 | chaman
# Processing Record 13 of Set 6 | wuda
# Processing Record 14 of Set 6 | afanasyevo
# City not found. Skipping...
# Processing Record 15 of Set 6 | timra
# Processing Record 16 of Set 6 | winnemucca
# Processing Record 17 of Set 6 | ayagoz
# Processing Record 18 of Set 6 | victoria
# Processing Record 19 of Set 6 | sitka
# Processing Record 20 of Set 6 | gazanjyk
# Processing Record 21 of Set 6 | dong hoi
# Processing Record 22 of Set 6 | tenkodogo
# Processing Record 23 of Set 6 | tilichiki
# Processing Record 24 of Set 6 | matara
# Processing Record 25 of Set 6 | senanga
# Processing Record 26 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 6 | kahului
# Processing Record 28 of Set 6 | flin flon
# Processing Record 29 of Set 6 | tutoia
# Processing Record 30 of Set 6 | quelimane
# Processing Record 31 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 6 | young
# Processing Record 33 of Set 6 | praia
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | wageningen
# Processing Record 36 of Set 6 | mantua
# Processing Record 37 of Set 6 | treinta y tres
# Processing Record 38 of Set 6 | pinega
# Processing Record 39 of Set 6 | leningradskiy
# Processing Record 40 of Set 6 | siniscola
# Processing Record 41 of Set 6 | khandagayty
# Processing Record 42 of Set 6 | spassk-ryazanskiy
# Processing Record 43 of Set 6 | atbasar
# Processing Record 44 of Set 6 | opuwo
# Processing Record 45 of Set 6 | petrozavodsk
# Processing Record 46 of Set 6 | umm kaddadah
# Processing Record 47 of Set 6 | vilhena
# Processing Record 48 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 6 | chum phae
# Processing Record 50 of Set 6 | scarborough
# Processing Record 1 of Set 7 | nioro
# Processing Record 2 of Set 7 | makokou
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | cravo norte
# Processing Record 5 of Set 7 | valparaiso
# Processing Record 6 of Set 7 | faya
# Processing Record 7 of Set 7 | banda aceh
# Processing Record 8 of Set 7 | torbat-e jam
# Processing Record 9 of Set 7 | wenling
# Processing Record 10 of Set 7 | carmen
# Processing Record 11 of Set 7 | lebu
# Processing Record 12 of Set 7 | hithadhoo
# Processing Record 13 of Set 7 | batesville
# Processing Record 14 of Set 7 | atherton
# Processing Record 15 of Set 7 | inongo
# Processing Record 16 of Set 7 | kachiry
# Processing Record 17 of Set 7 | micomeseng
# Processing Record 18 of Set 7 | saldanha
# Processing Record 19 of Set 7 | khani
# Processing Record 20 of Set 7 | ottumwa
# Processing Record 21 of Set 7 | henties bay
# Processing Record 22 of Set 7 | kiama
# Processing Record 23 of Set 7 | gat
# Processing Record 24 of Set 7 | luwuk
# Processing Record 25 of Set 7 | la ronge
# Processing Record 26 of Set 7 | makung
# City not found. Skipping...
# Processing Record 27 of Set 7 | marawi
# Processing Record 28 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 7 | zhigansk
# Processing Record 30 of Set 7 | alta floresta
# Processing Record 31 of Set 7 | kudahuvadhoo
# Processing Record 32 of Set 7 | batticaloa
# Processing Record 33 of Set 7 | meadow lake
# Processing Record 34 of Set 7 | ndele
# Processing Record 35 of Set 7 | krasnoborsk
# Processing Record 36 of Set 7 | tumpat
# Processing Record 37 of Set 7 | frankfort
# Processing Record 38 of Set 7 | brooks
# Processing Record 39 of Set 7 | esperance
# Processing Record 40 of Set 7 | san jose
# Processing Record 41 of Set 7 | husavik
# Processing Record 42 of Set 7 | jalingo
# Processing Record 43 of Set 7 | san quintin
# Processing Record 44 of Set 7 | mokhsogollokh
# Processing Record 45 of Set 7 | cherskiy
# Processing Record 46 of Set 7 | chapais
# Processing Record 47 of Set 7 | huesca
# Processing Record 48 of Set 7 | ayan
# Processing Record 49 of Set 7 | magistralnyy
# Processing Record 50 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 8 | bagdarin
# Processing Record 2 of Set 8 | emporia
# Processing Record 3 of Set 8 | nagua
# Processing Record 4 of Set 8 | luba
# Processing Record 5 of Set 8 | port elizabeth
# Processing Record 6 of Set 8 | salalah
# Processing Record 7 of Set 8 | san cristobal
# Processing Record 8 of Set 8 | sagua la grande
# Processing Record 9 of Set 8 | naifaru
# Processing Record 10 of Set 8 | acarau
# Processing Record 11 of Set 8 | trairi
# Processing Record 12 of Set 8 | ust-nera
# Processing Record 13 of Set 8 | brigantine
# Processing Record 14 of Set 8 | santa marinella
# Processing Record 15 of Set 8 | sol-iletsk
# Processing Record 16 of Set 8 | gilgit
# Processing Record 17 of Set 8 | menongue
# Processing Record 18 of Set 8 | alugan
# Processing Record 19 of Set 8 | lagoa
# Processing Record 20 of Set 8 | zirandaro
# Processing Record 21 of Set 8 | xiongshi
# City not found. Skipping...
# Processing Record 22 of Set 8 | les cayes
# Processing Record 23 of Set 8 | puerto maldonado
# Processing Record 24 of Set 8 | darhan
# Processing Record 25 of Set 8 | geraldton
# Processing Record 26 of Set 8 | burnie
# Processing Record 27 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 8 | nador
# Processing Record 29 of Set 8 | atambua
# Processing Record 30 of Set 8 | okha
# Processing Record 31 of Set 8 | abu zabad
# Processing Record 32 of Set 8 | arraial do cabo
# Processing Record 33 of Set 8 | margate
# Processing Record 34 of Set 8 | kavieng
# Processing Record 35 of Set 8 | kampot
# Processing Record 36 of Set 8 | piste
# Processing Record 37 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 8 | moussoro
# Processing Record 39 of Set 8 | chippewa falls
# Processing Record 40 of Set 8 | lazaro cardenas
# Processing Record 41 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 8 | northam
# Processing Record 43 of Set 8 | solnechnyy
# Processing Record 44 of Set 8 | catabola
# Processing Record 45 of Set 8 | nome
# Processing Record 46 of Set 8 | kollo
# Processing Record 47 of Set 8 | kokkarion
# Processing Record 48 of Set 8 | mao
# Processing Record 49 of Set 8 | hambantota
# Processing Record 50 of Set 8 | chardara
# Processing Record 1 of Set 9 | bandarbeyla
# Processing Record 2 of Set 9 | ucluelet
# Processing Record 3 of Set 9 | pouembout
# Processing Record 4 of Set 9 | pimentel
# Processing Record 5 of Set 9 | taonan
# Processing Record 6 of Set 9 | matagami
# Processing Record 7 of Set 9 | swan hill
# Processing Record 8 of Set 9 | kayerkan
# Processing Record 9 of Set 9 | rawson
# Processing Record 10 of Set 9 | college
# Processing Record 11 of Set 9 | aasiaat
# Processing Record 12 of Set 9 | raudeberg
# Processing Record 13 of Set 9 | talaya
# Processing Record 14 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 9 | smithers
# Processing Record 16 of Set 9 | myingyan
# Processing Record 17 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 9 | ponta delgada
# Processing Record 19 of Set 9 | santa maria
# Processing Record 20 of Set 9 | bijela
# Processing Record 21 of Set 9 | wanaka
# Processing Record 22 of Set 9 | lyubech
# Processing Record 23 of Set 9 | vila
# Processing Record 24 of Set 9 | nantucket
# Processing Record 25 of Set 9 | balyaga
# Processing Record 26 of Set 9 | pangkalanbuun
# Processing Record 27 of Set 9 | comodoro rivadavia
# Processing Record 28 of Set 9 | shingu
# Processing Record 29 of Set 9 | port lincoln
# Processing Record 30 of Set 9 | giyon
# Processing Record 31 of Set 9 | san andres
# Processing Record 32 of Set 9 | the valley
# Processing Record 33 of Set 9 | maldonado
# Processing Record 34 of Set 9 | kuragino
# Processing Record 35 of Set 9 | gwadar
# Processing Record 36 of Set 9 | zyryanka
# Processing Record 37 of Set 9 | bonga
# Processing Record 38 of Set 9 | wuxi
# Processing Record 39 of Set 9 | medea
# Processing Record 40 of Set 9 | kulhudhuffushi
# Processing Record 41 of Set 9 | cumana
# Processing Record 42 of Set 9 | danao
# Processing Record 43 of Set 9 | sao sebastiao
# Processing Record 44 of Set 9 | acajutla
# Processing Record 45 of Set 9 | rodrigues alves
# Processing Record 46 of Set 9 | xinyu
# Processing Record 47 of Set 9 | karacakoy
# Processing Record 48 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 49 of Set 9 | abu kamal
# Processing Record 50 of Set 9 | mnogovershinnyy
# Processing Record 1 of Set 10 | sioux lookout
# Processing Record 2 of Set 10 | coihaique
# Processing Record 3 of Set 10 | ruteng
# Processing Record 4 of Set 10 | marsh harbour
# Processing Record 5 of Set 10 | bourail
# Processing Record 6 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 10 | miraflores
# Processing Record 8 of Set 10 | inhambane
# Processing Record 9 of Set 10 | constitucion
# Processing Record 10 of Set 10 | dingle
# Processing Record 11 of Set 10 | saint-claude
# Processing Record 12 of Set 10 | fort frances
# Processing Record 13 of Set 10 | shar
# Processing Record 14 of Set 10 | haines junction
# Processing Record 15 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 10 | zanesville
# Processing Record 18 of Set 10 | alizai
# Processing Record 19 of Set 10 | la asuncion
# Processing Record 20 of Set 10 | westlake village
# Processing Record 21 of Set 10 | huilong
# Processing Record 22 of Set 10 | coracora
# Processing Record 23 of Set 10 | reefton
# City not found. Skipping...
# Processing Record 24 of Set 10 | cordoba
# Processing Record 25 of Set 10 | vila franca do campo
# Processing Record 26 of Set 10 | katav-ivanovsk
# Processing Record 27 of Set 10 | irara
# Processing Record 28 of Set 10 | labe
# Processing Record 29 of Set 10 | mayumba
# Processing Record 30 of Set 10 | tres picos
# Processing Record 31 of Set 10 | jiangkou
# Processing Record 32 of Set 10 | kemijarvi
# Processing Record 33 of Set 10 | rio grande
# Processing Record 34 of Set 10 | zhoucheng
# Processing Record 35 of Set 10 | culebra
# Processing Record 36 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 10 | praia da vitoria
# Processing Record 38 of Set 10 | beidao
# Processing Record 39 of Set 10 | richards bay
# Processing Record 40 of Set 10 | santa rosalia
# Processing Record 41 of Set 10 | koutiala
# Processing Record 42 of Set 10 | tual
# Processing Record 43 of Set 10 | vetluzhskiy
# Processing Record 44 of Set 10 | bucerias
# Processing Record 45 of Set 10 | princeville
# Processing Record 46 of Set 10 | frederico westphalen
# Processing Record 47 of Set 10 | seoul
# Processing Record 48 of Set 10 | huaiyin
# Processing Record 49 of Set 10 | starobaltachevo
# Processing Record 50 of Set 10 | caravelas
# Processing Record 1 of Set 11 | mountain home
# Processing Record 2 of Set 11 | ankang
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | isangel
# Processing Record 5 of Set 11 | phuket
# Processing Record 6 of Set 11 | bathsheba
# Processing Record 7 of Set 11 | lumeje
# Processing Record 8 of Set 11 | north bend
# Processing Record 9 of Set 11 | kokopo
# Processing Record 10 of Set 11 | amga
# Processing Record 11 of Set 11 | abu dhabi
# Processing Record 12 of Set 11 | beringovskiy
# Processing Record 13 of Set 11 | chekhov
# Processing Record 14 of Set 11 | mani
# Processing Record 15 of Set 11 | nuuk
# Processing Record 16 of Set 11 | panguna
# Processing Record 17 of Set 11 | ludvika
# Processing Record 18 of Set 11 | pemangkat
# Processing Record 19 of Set 11 | svetlyy
# Processing Record 20 of Set 11 | divnomorskoye
# Processing Record 21 of Set 11 | cairns
# Processing Record 22 of Set 11 | palmer
# Processing Record 23 of Set 11 | ambanja
# Processing Record 24 of Set 11 | panama city
# Processing Record 25 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 11 | biltine
# Processing Record 27 of Set 11 | altay
# Processing Record 28 of Set 11 | saint marys
# Processing Record 29 of Set 11 | berlevag
# Processing Record 30 of Set 11 | oxford
# Processing Record 31 of Set 11 | nangomba
# Processing Record 32 of Set 11 | valley city
# Processing Record 33 of Set 11 | kita
# Processing Record 34 of Set 11 | dongning
# Processing Record 35 of Set 11 | touros
# Processing Record 36 of Set 11 | surgut
# Processing Record 37 of Set 11 | meulaboh
# Processing Record 38 of Set 11 | klaksvik
# Processing Record 39 of Set 11 | kalia
# Processing Record 40 of Set 11 | sapa
# Processing Record 41 of Set 11 | salta
# Processing Record 42 of Set 11 | port augusta
# Processing Record 43 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 11 | tengzhou
# Processing Record 45 of Set 11 | namibe
# Processing Record 46 of Set 11 | svobodnyy
# Processing Record 47 of Set 11 | basco
# Processing Record 48 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 11 | dongli
# Processing Record 50 of Set 11 | saint-pierre
# Processing Record 1 of Set 12 | adrar
# Processing Record 2 of Set 12 | casma
# Processing Record 3 of Set 12 | kondinskoye
# Processing Record 4 of Set 12 | thinadhoo
# Processing Record 5 of Set 12 | nizhniy tsasuchey
# Processing Record 6 of Set 12 | roma
# Processing Record 7 of Set 12 | mandiana
# Processing Record 8 of Set 12 | leshukonskoye
# Processing Record 9 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 10 of Set 12 | salinopolis
# Processing Record 11 of Set 12 | castro verde
# Processing Record 12 of Set 12 | martaban
# Processing Record 13 of Set 12 | ariogala
# Processing Record 14 of Set 12 | agirish
# Processing Record 15 of Set 12 | vardo
# Processing Record 16 of Set 12 | bealanana
# Processing Record 17 of Set 12 | tiarei
# Processing Record 18 of Set 12 | sayyan
# Processing Record 19 of Set 12 | mehamn
# Processing Record 20 of Set 12 | sao bartolomeu de messines
# Processing Record 21 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 12 | gelibolu
# Processing Record 23 of Set 12 | rincon
# Processing Record 24 of Set 12 | catalina
# Processing Record 25 of Set 12 | nago
# Processing Record 26 of Set 12 | havre
# Processing Record 27 of Set 12 | juneau
# Processing Record 28 of Set 12 | waterloo
# Processing Record 29 of Set 12 | aquidauana
# Processing Record 30 of Set 12 | vieste
# Processing Record 31 of Set 12 | tarime
# Processing Record 32 of Set 12 | huanan
# Processing Record 33 of Set 12 | iwaki
# Processing Record 34 of Set 12 | norwich
# Processing Record 35 of Set 12 | lubbock
# Processing Record 36 of Set 12 | hoquiam
# Processing Record 37 of Set 12 | omaruru
# Processing Record 38 of Set 12 | rorvik
# Processing Record 39 of Set 12 | port moresby
# Processing Record 40 of Set 12 | kindu
# Processing Record 41 of Set 12 | itoman
# Processing Record 42 of Set 12 | la romana
# Processing Record 43 of Set 12 | pedernales
# Processing Record 44 of Set 12 | buraydah
# Processing Record 45 of Set 12 | kolyvan
# Processing Record 46 of Set 12 | wamba
# Processing Record 47 of Set 12 | sabratah
# Processing Record 48 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 12 | deer lake
# Processing Record 50 of Set 12 | akropong
# Processing Record 1 of Set 13 | hauterive
# Processing Record 2 of Set 13 | turayf
# Processing Record 3 of Set 13 | edd
# Processing Record 4 of Set 13 | eenhana
# Processing Record 5 of Set 13 | pangnirtung
# Processing Record 6 of Set 13 | kilindoni
# Processing Record 7 of Set 13 | yima
# Processing Record 8 of Set 13 | cucuta
# Processing Record 9 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 13 | mazyr
# Processing Record 11 of Set 13 | changping
# Processing Record 12 of Set 13 | tarrafal
# Processing Record 13 of Set 13 | broken hill
# Processing Record 14 of Set 13 | sorong
# Processing Record 15 of Set 13 | kununurra
# Processing Record 16 of Set 13 | ihosy
# Processing Record 17 of Set 13 | turukhansk
# Processing Record 18 of Set 13 | vizinga
# Processing Record 19 of Set 13 | shache
# Processing Record 20 of Set 13 | gorontalo
# Processing Record 21 of Set 13 | little chute
# Processing Record 22 of Set 13 | garissa
# Processing Record 23 of Set 13 | ruidoso
# Processing Record 24 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 25 of Set 13 | kieta
# Processing Record 26 of Set 13 | bijie
# Processing Record 27 of Set 13 | gondanglegi
# Processing Record 28 of Set 13 | ambulu
# Processing Record 29 of Set 13 | olafsvik
# Processing Record 30 of Set 13 | kasongo-lunda
# Processing Record 31 of Set 13 | vila velha
# Processing Record 32 of Set 13 | dargaville
# Processing Record 33 of Set 13 | hanzhong
# Processing Record 34 of Set 13 | si sa ket
# Processing Record 35 of Set 13 | apac
# Processing Record 36 of Set 13 | bud
# Processing Record 37 of Set 13 | abonnema
# Processing Record 38 of Set 13 | fort nelson
# Processing Record 39 of Set 13 | khasan
# Processing Record 40 of Set 13 | vestmannaeyjar
# Processing Record 41 of Set 13 | kyzyl-suu
# Processing Record 42 of Set 13 | labuan
# Processing Record 43 of Set 13 | paciran
# Processing Record 44 of Set 13 | bosaso
# Processing Record 45 of Set 13 | salina
# Processing Record 46 of Set 13 | vedaranniyam
# City not found. Skipping...
# Processing Record 47 of Set 13 | rio gallegos
# Processing Record 48 of Set 13 | igarka
# Processing Record 49 of Set 13 | batemans bay
# Processing Record 50 of Set 13 | nsanje
# Processing Record 1 of Set 14 | birjand
# Processing Record 2 of Set 14 | pombal
# Processing Record 3 of Set 14 | chlorakas
# Processing Record 4 of Set 14 | houma
# Processing Record 5 of Set 14 | hovd
# Processing Record 6 of Set 14 | virginia beach
# Processing Record 7 of Set 14 | aguimes
# Processing Record 8 of Set 14 | shu
# Processing Record 9 of Set 14 | tahara
# Processing Record 10 of Set 14 | praya
# Processing Record 11 of Set 14 | coruripe
# Processing Record 12 of Set 14 | jalu
# Processing Record 13 of Set 14 | sambava
# Processing Record 14 of Set 14 | talkha
# Processing Record 15 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 14 | vagur
# Processing Record 17 of Set 14 | novoomskiy
# Processing Record 18 of Set 14 | nova odesa
# Processing Record 19 of Set 14 | aswan
# Processing Record 20 of Set 14 | inverness
# Processing Record 21 of Set 14 | lomovka
# Processing Record 22 of Set 14 | cheyenne
# Processing Record 23 of Set 14 | dhidhdhoo
# Processing Record 24 of Set 14 | baracoa
# Processing Record 25 of Set 14 | south lake tahoe
# Processing Record 26 of Set 14 | batagay-alyta
# Processing Record 27 of Set 14 | beloha
# Processing Record 28 of Set 14 | ocean city
# Processing Record 29 of Set 14 | kovdor
# Processing Record 30 of Set 14 | wilmington
# Processing Record 31 of Set 14 | sao filipe
# Processing Record 32 of Set 14 | rovaniemi
# Processing Record 33 of Set 14 | klyuchi
# Processing Record 34 of Set 14 | hauknes
# Processing Record 35 of Set 14 | odweyne
# Processing Record 36 of Set 14 | ozernovskiy
# Processing Record 37 of Set 14 | mastic beach
# Processing Record 38 of Set 14 | el grullo
# Processing Record 39 of Set 14 | gravelbourg
# Processing Record 40 of Set 14 | alyangula
# Processing Record 41 of Set 14 | orel-izumrud
# Processing Record 42 of Set 14 | arona
# Processing Record 43 of Set 14 | susangerd
# Processing Record 44 of Set 14 | melipilla
# Processing Record 45 of Set 14 | paita
# Processing Record 46 of Set 14 | ruston
# Processing Record 47 of Set 14 | avera
# Processing Record 48 of Set 14 | manakara
# Processing Record 49 of Set 14 | marsa matruh
# Processing Record 50 of Set 14 | arrecife
# Processing Record 1 of Set 15 | kuching
# Processing Record 2 of Set 15 | mednogorsk
# Processing Record 3 of Set 15 | martapura
# Processing Record 4 of Set 15 | hatillo
# Processing Record 5 of Set 15 | yongan
# Processing Record 6 of Set 15 | natal
# Processing Record 7 of Set 15 | kupang
# Processing Record 8 of Set 15 | cayenne
# Processing Record 9 of Set 15 | manaure
# Processing Record 10 of Set 15 | kaihua
# Processing Record 11 of Set 15 | belmonte
# Processing Record 12 of Set 15 | lovozero
# Processing Record 13 of Set 15 | port macquarie
# Processing Record 14 of Set 15 | louth
# Processing Record 15 of Set 15 | santa rosa
# Processing Record 16 of Set 15 | belaya gora
# Processing Record 17 of Set 15 | sungurlu
# Processing Record 18 of Set 15 | hamilton
# Processing Record 19 of Set 15 | surgana
# Processing Record 20 of Set 15 | sao jose da coroa grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     47.86        66          40
# 1       Rikitea      PF -23.1203 -134.9692     77.41        80          46
# 2  Saint George      US  37.1041 -113.5841     59.47        42           1
# 3       Tambura      SS   5.6000   27.4667     77.97        33          95
# 4        Torbay      CA  47.6666  -52.7314     40.57        82          75
#
#    Wind Speed Current Description
# 0       24.16          light rain
# 1       10.40          light rain
# 2        1.99           clear sky
# 3        4.12     overcast clouds
# 4       24.16       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
